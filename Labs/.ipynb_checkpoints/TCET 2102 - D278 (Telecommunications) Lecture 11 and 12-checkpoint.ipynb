# %% [markdown]
# **Name: Christ-Brian Amedjonekou**
# **Date: 11/27/2018**
# **TCET 2102 (Analog and Digital Telephone) Lectures 11 and 12 (Review)**
# **Fall 2018, Section: D278, Code: 37580**
# **Instructor: Layth Qaseer**

# %% [markdown]
# ## Data and Signals
#
# * When you try to send things through physical mediums (Physical Layer of the OSI Model) you are just transmitting data across network connections. Sounds obvious, this should be considered common sense.
#     $$\space$$
#     * To be transmitted, data must be transformed to electromagnetic signals.
#
#
# * This leads the the next thing, Analog and Digital.
#
# ## Analog and Digital
#
# * Both data and the electromagnetic signals that represent them can be either analog (electromagnetic waves are analog) or digital in form.
#
# * Data can be analog or digital. The term analog data refers to information that is continuous (Analog data takes on continuous values); digital data refers to information that has discrete states (Digital data takes on discrete values).
#
# ## Periodic and Nonperiodic Signals
#
# * Both analog and digital signals can take one of two forms: periodic or nonperiodic (sometimes refer to as aperiodic, because the prefix a in Greek means “non”)
#
#
# * A periodic signal completes a pattern within a measurable time frame, called a period, and repeats that pattern over subsequent identical periods. The completion of one full pattern is called a cycle. A nonperiodic signal changes without exhibiting a pattern or cycle that repeats over time.
#
#
# * In data communications, we commonly use periodic analog signals (because they need less bandwidth) and nonperiodic digital signals (because they can represent variation in data).
# $$\space$$
# $$\text{Periodic Analog (Sinusoidal Wave) }=V_P\sin(\omega t + \theta)$$
# $$\space$$
#     * where:
# $$\text{Voltage Peak (Amplitude)} = V_P$$
# $$\text{Voltage Peak to Peak (Amplitude)} = V_{P-P} = 2*V_P$$
# $$\omega = 2 \pi f = \text{angular velocity}$$
# $$f = \frac{1}{T}; \text{ frequency}=\frac{1}{\text{Period}}$$
#
#
# * **Frequency is important. We describe it as the following:**
#     $$\space$$
#     * Frequency is the rate of change with respect to time. Change in a short span of time means high frequency. Change over a long span of time means low frequency.
#     $$\space$$
#         * **Frequency is infinite if it jumps from one state to the next (Discrete Case).**
#         * **Frequency is zero if it doesn't change at all with time. Flat all the way through (DC Case).**
#
#
# * **Phase is also important. We describe it below:**
#     $$\space$$
#     * Phase describes the position of the waveform relative to time 0.
#         $$\space$$
#         * If the wave is shifted to the left (+n)
#         * If the wave is shifted to the right (-n)
#
#
# * **Wavelength is another characteristic of a signal traveling through a transmission medium. Wavelength binds the period or the frequency of a simple sine wave to the propagation speed of the medium.**
#     $$\space$$
#     * While the frequency of a signal is independent of the medium, the wavelength depends on both the frequency and the medium. Wavelength is a property of any type of signal.
#     * The wavelength is the distance a simple signal can travel in one period.
#
#     $$\text{Wavelength} = \text{propagation speed} * \text{period} = \frac{\text{propagation speed}}{\text{frequency}}; \space \mathbf{\lambda = \frac{c}{f}}$$     $$\space$$
#     * The propagation speed of electromagnetic signals depends on the medium and on the frequency of the signal.
#
# **Time and Frequency**
#
# * A sine wave is comprehensively defined by its amplitude, frequency, and phase. We have been showing a sine wave by using what is called a time-domain plot. The time-domain plot shows changes in signal amplitude with respect to time (it is an amplitude-versus-time plot). Phase is not explicitly shown on a time-domain plot.
#
#
# * To show the relationship between amplitude and frequency, we can use what is called a frequency-domain plot. A frequency-domain plot is concerned with only the peak value and the frequency. Changes of amplitude during one period are not shown.

# %%
from IPython.display import Image as i
i(filename= '/Users/Chris/Desktop/Images/TCET45.png', width= 500, height= 500)

# %% [markdown]
# ***"It is obvious that the frequency domain is easy to plot and conveys the information that one can find in a time domain plot."***
#
# * The advantage of the frequency domain is that we can immediately see the values of the frequency and peak amplitude. A complete sine wave is represented by one spike.
#     $$\space$$
#     * The position of the spike shows the frequency; its height shows the peak amplitude.
#
#
# ### Composite Signal
#
# * A single-frequency sine wave is not useful in data communications; we need to send a composite signal, a signal made of many simple sine waves.
#
#
# * A composite signal can be periodic or nonperiodic:
#     $$\space$$
#     * A periodic composite signal can be decomposed into a series of simple sine waves with discrete frequencies— frequencies that have integer values (1, 2, 3, and so on).
#     $$\space$$
#     * A nonperiodic composite signal can be decomposed into a combination of an infinite number of simple sine waves with continuous frequencies, frequencies that have real values.
#     $$\space$$
#     * It is very difficult to manually decompose this signal into a series of simple sine waves. However, there are tools, both hardware and software, that can help us do the job.

# %%
i(filename= '/Users/Chris/Desktop/Images/TCET46.png', width= 500, height= 500)

# %% [markdown]
# ***One such method: Fourier Analysis***
#
# * **The amplitude of the sine wave with frequency f is almost the same as the peak amplitude of the composite signal. The amplitude of the sine wave with frequency 3f is one-third of that of the first, and the amplitude of the sine wave with frequency 9f is one-ninth of the first. The frequency of the sine wave with frequency f is the same as the frequency of the composite signal; it is called the fundamental frequency, or first harmonic. The sine wave with frequency 3f has a frequency of 3 times the fundamental frequency; it is called the third harmonic. The third sine wave with frequency 9f has a frequency of 9 times the fundamental frequency; it is called the ninth harmonic.**
#
#
# * **Note that the frequency decomposition of the signal is discrete; it has frequencies f, 3f, and 9f. Because f is an integral number, 3f and 9f are also integral numbers. There are no frequencies such as 1.2f or 2.6f. The frequency domain of a periodic composite signal is always made of discrete spikes.**
#
# ### Non-Composite Periodic Signal
#
# * It can be the signal created by a microphone or a telephone set when a word or two is pronounced. In this case, the composite signal cannot be periodic, because that implies that we are repeating the same word or words with exactly the same tone.
#
#
# * **Time-Domain Representation:**
#     $$\space$$
#     * Infinite number of simple sine frequencies.
#     * Example: Although the number of frequencies in a human voice is infinite, the range is limited. A normal human being can create a continuous range of frequencies between 0 and 4 kHz.
#
#
# * **Frequency Decomposition:**
#     $$\space$$
#     * is a continuous curve.
#     * There are an infinite number of frequencies between 0.0 and 4000.0 (real values).
#     * To find the amplitude related to frequency f, we draw a vertical line at f to intersect the envelope curve. The height of the vertical line is the amplitude of the corresponding frequency.

# %%
i(filename= '/Users/Chris/Desktop/Images/TCET47.png', width= 500, height= 500)

# %% [markdown]
# ### Bandwidth
#
# * The bandwidth of a composite signal is the difference between the highest and the lowest frequencies contained in that signal.

# %%
i(filename= '/Users/Chris/Desktop/Images/TCET47.png', width= 500, height= 500)

# %% [markdown]
# ***Discrete (Periodic) Bandwidth***

# %%
i(filename= '/Users/Chris/Desktop/Images/TCET49.png', width= 500, height= 500)

# %% [markdown]
# ***Continuous (Non-periodic) Bandwidth***

# %%
i(filename= '/Users/Chris/Desktop/Images/TCET50.png', width= 500, height= 500)

# %% [markdown]
# ### Digital Signals
#
# * In addition to being represented by an analog signal, information can also be represented by a digital signal.
#
#
# * A digital signal can have more than two levels. It's determined by the number of bits ($2^n$) used
#     $$\space$$
#     * e.g: **1-bit ( $2^1 =$ 2 numbers) "0, 1"; 2-bit ( $2^2 =$ 4 numbers), "00, 01, 10, 11".**

# %%
i(filename= '/Users/Chris/Desktop/Images/TCET51.png', width= 500, height= 500)

# %% [markdown]
#  ***Bit-Rate***
#
# * Number of bits per second (Bits/Sec (**bps**))
# * Most digital signals are nonperiodic, and thus period and frequency are not appropriate characteristics. Another term — bit rate (instead of frequency) — is used to describe digital signals.
#
#
# ***Bit-Length***
#
# * We discussed the concept of the wavelength for an analog signal: the distance one cycle occupies on the transmission medium. We can define something similar for a digital signal: the bit length. The bit length is the distance one bit occupies on the transmission medium.
#
# $$\text{Bit Length} = \text{Propogation Speed}+\text{Bit Duration}$$
#
#
# ***Digital Signal as a Composite Analog Signal***
#
# * Based on Fourier analysis, a digital signal is a composite analog signal.
#
#
# * The bandwidth is infinite.
#
#
# * We can intuitively come up with this concept when we consider a digital signal. A digital signal, in the time domain, comprises connected vertical and horizontal line segments.
#
#
# * A vertical line in the time domain means a frequency of infinity (sudden change in time); a horizontal line in the time domain means a frequency of zero (no change in time).
#
#
# * Going from a frequency of zero to a frequency of infinity (and vice versa) implies all frequencies in between are part of the domain.
#
#
# * If the digital signal is periodic, which is rare in data communications, the decomposed signal has a frequency-domain representation with an infinite bandwidth and discrete frequencies.
#
#
# * If the digital signal is nonperiodic, the decomposed signal still has an infinite bandwidth, but the frequencies are continuous.

# %%
i(filename= '/Users/Chris/Desktop/Images/TCET52.png', width= 500, height= 500)

# %% [markdown]
# ### Transmission of Digital Signals
#
# * The fundamental question is, How can we send a digital signal from point A to point B? We can transmit a digital signal by using one of two different approaches: baseband transmission or broadband transmission (using modulation).
#     $$\space$$
#     * Baseband transmission means sending a digital signal over a channel without changing the digital signal to an analog signal.
#     $$\space$$
#     * Broadband transmission means sending a digital signal over a channel while changing the digital signal to an analog signal and back into a digital signal during the transmission cycle.

# %% [markdown]
# ### Lecture 11 Review Questions (Q: 32-35, 38, 39)

# %%
def wavelength(propogation_speed, frequency= 1, period= 1, hvePeriod= False):
    """Takes in two variables; Two variables are preset. If 'hvePeriod == True'.
    'hvePeriod' checks to see if the user has the value of the period instead of
    frequency."""
    if hvePeriod == False:
        return propogation_speed/frequency
    else:
        return propogation_speed * period

# %% [markdown]
# ***Set 1***
#
# 32. A signal has passed through three cascaded amplifiers, each with a 4 dB gain. What is the total gain? How much is the signal amplified?

# %%
import math as m
totalgain = 4 * 3
AmplifiedSignal = m.pow(10, totalgain/10)
print("Total Gain: {}\nAmplified Signal: {}".format(totalgain, AmplifiedSignal))
# Out:
# Total Gain: 12
# Amplified Signal: 15.848931924611133

# %% [markdown]
# 33. If the bandwidth of the channel is 5 Kbps, how long does it take to send a frame of 100,000 bits out of this device?

# %% [markdown]
# 34. The light of the sun takes approximately eight minutes to reach the earth. What is the distance between the sun and the earth?

# %% [markdown]
# 35. A signal has a wavelength of 1 μm in air. How far can the front of the wave travel during 1000 periods?

# %% [markdown]
# ***Set 2***
#
# 38. A file contains 2 million bytes. How long does it take to download this file using a 56-Kbps channel? 1-Mbps channel?

# %% [markdown]
# 39. A computer monitor has a resolution of 1200 by 1000 pixels. If each pixel uses 1024 colors, how many bits are needed to send the complete contents of a screen?

# %% [markdown]
# ### ANALOG-TO-DIGITAL CONVERSION
